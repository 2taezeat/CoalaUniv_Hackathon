# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv('bubble.csv')

# %%
data
# Out:
#                                      제품명(ID)  Unnamed: 1  브랜드  SSD용량  HDD용량  \
# 0              LG전자 2019 울트라PC 15UD590-GX50K           1    8    256      0
# 1              LG전자 2019 울트라PC 15UD590-GX50K           2    8    512      0
# 2              LG전자 2019 울트라PC 15UD590-GX50K           3    8    256    512
# 3              LG전자 2019 울트라PC 15UD590-GX50K           4    8    256   1024
# 4                 LG전자 2019 그램 15ZD990-VX50K           5    8    256      0
# 5                 LG전자 2019 그램 15ZD990-VX50K           6    8   2048      0
# 6                 LG전자 2019 그램 15ZD990-VX50K           7    8    512      0
# 7                 LG전자 2019 그램 15ZD990-VX50K           8    8   1024      0
# 8                 LG전자 2019 그램 15ZD990-VX50K           9    8    256      0
# 9                 LG전자 2019 그램 15ZD990-VX50K          10    8   1024      0
# 10               APPLE 맥북프로 2019년형 MV912KH/A          11    2    512      0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data.iloc[:,1:-1], data.iloc[:,-1])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2222 entries, 1252 to 2462
# Data columns (total 23 columns):
# Unnamed: 1    2222 non-null int64
# 브랜드           2222 non-null int64
# SSD용량         2222 non-null int64
# HDD용량         2222 non-null int64
# RAM용량         2222 non-null int64
# CPU제조사        2222 non-null int64
# CPU성능         2222 non-null int64
# 코어 개수         2222 non-null int64
# 화면크기          2222 non-null float64
# 해상도           2222 non-null int64
# DDR           2222 non-null int64
# SSD종류         2222 non-null int64
# GPU 제조사       2222 non-null int64
# GPU 성능        2222 non-null int64
# VRAM          2222 non-null int64
# HDMI          2222 non-null int64
# 단자            2222 non-null int64
# 숫자키패드         2222 non-null int64
# 무게            2222 non-null float64
# 두께            2222 non-null float64
# 멀티리더기 여부      2222 non-null int64
# 배터리           2222 non-null float64
# 운영체제          2222 non-null int64
# dtypes: float64(4), int64(19)
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 741 entries, 2062 to 2440
# Data columns (total 23 columns):
# Unnamed: 1    741 non-null int64
# 브랜드           741 non-null int64
# SSD용량         741 non-null int64
# HDD용량         741 non-null int64
# RAM용량         741 non-null int64
# CPU제조사        741 non-null int64
# CPU성능         741 non-null int64
# 코어 개수         741 non-null int64
# 화면크기          741 non-null float64
# 해상도           741 non-null int64
# DDR           741 non-null int64
# SSD종류         741 non-null int64
# GPU 제조사       741 non-null int64
# GPU 성능        741 non-null int64
# VRAM          741 non-null int64
# HDMI          741 non-null int64
# 단자            741 non-null int64
# 숫자키패드         741 non-null int64
# 무게            741 non-null float64
# 두께            741 non-null float64
# 멀티리더기 여부      741 non-null int64
# 배터리           741 non-null float64
# 운영체제          741 non-null int64
# dtypes: float64(4), int64(19)
# memory usage: 138.9 KB

# %%
X_train.head()
# Out:
#       Unnamed: 1  브랜드  SSD용량  HDD용량  RAM용량  CPU제조사  CPU성능  코어 개수  화면크기  해상도  \
# 1252        1253   13    256      0      8       1   8799      2  15.6    1
# 2076        2077    3    256      0      4       1   7677      4  14.0    1
# 1362        1363   13    512      0      8       1   6783      2  13.3    3
# 1678        1679   13    256      0      8       1   7989      4  15.0    1
# 2227        2228   13   2048      0     16       1   8290      4  15.0    1
#
#       ...  GPU 성능  VRAM  HDMI  단자  숫자키패드    무게    두께  멀티리더기 여부   배터리  운영체제
# 1252  ...    1362     2     1   2      1  1.80  20.8         1  43.0     0
# 2076  ...    1057     0     0   3      0  1.20  14.8         1  39.0     3
# 1362  ...     839     0     1   2      0  1.30  14.9         1  39.0     3
# 1678  ...    1057     0     0   2      0  1.51  16.9         1  54.0     3
# 2227  ...    2204     2     1   3      0  1.29  15.4         1  75.0     3
#
# [5 rows x 23 columns]

# %%
X_test.head()
# Out:
#       Unnamed: 1  브랜드  SSD용량  HDD용량  RAM용량  CPU제조사  CPU성능  코어 개수  화면크기  해상도  \
# 2062        2063    8    512      0      8       1   7677      4  15.6    1
# 2381        2382    8    128      0      8       1   3518      2  13.3    1
# 142          143   13    512      0      8       1   7989      4  13.3    1
# 209          210   10    512      0     16       1   9352      4  15.0    3
# 310          311   13   1024      0      4       1   7677      4  15.6    1
#
#       ...  GPU 성능  VRAM  HDMI  단자  숫자키패드    무게    두께  멀티리더기 여부   배터리  운영체제
# 2062  ...    1057     0     1   2      1  1.89  20.9         1  53.1     3
# 2381  ...     930     0     1   2      0  0.97  15.5         1  72.0     0
# 142   ...    1057     0     1   2      0  1.00  14.9         1  75.0     3
# 209   ...    9096     6     0   2      0  1.90  23.0         1  53.1     3
# 310   ...    2204     2     1   2      0  1.90  19.6         1  43.0     3
#
# [5 rows x 23 columns]

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
value3 = pd.DataFrame(X_test['Unnamed: 1'])

# %%
value3['answer'] = y_test

# %%
value3
# Out:
#       Unnamed: 1   answer
# 2062        2063  1001000
# 2381        2382   879000
# 142          143  1300000
# 209          210  3000000
# 310          311  1360000
# 651          652  1705000
# 92            93  2199000
# 1966        1967   903000
# 409          410   759000
# 1506        1507   990000
# 2293        2294   830000
# 1373        1374   769990
# 473          474  1697000
# 2740        2741   667000
# 1275        1276  1272040
# 1299        1300  1301490
# 1055        1056  1199000
# 984          985  1180000
# 654          655  1163000
# 2179        2180  1674000
# 87            88  1274000
# 1844        1845  1823000
# 2712        2713  1179000
# 1387        1388  1438990
# 1007        1008  1231000
# 1600        1601   555000
# 33            34  1649000
# 846          847  1199000
# 1782        1783   539000
# 185          186  1222000
# ...          ...      ...
# 238          239  2168000
# 2744        2745  1532000
# 83            84   629000
# ...

# %%
y_test
# Out:
# 2062    1001000
# 2381     879000
# 142     1300000
# 209     3000000
# 310     1360000
# 651     1705000
# 92      2199000
# 1966     903000
# 409      759000
# 1506     990000
# 2293     830000
# 1373     769990
# 473     1697000
# 2740     667000
# 1275    1272040
# 1299    1301490
# 1055    1199000
# 984     1180000
# 654     1163000
# 2179    1674000
# 87      1274000
# 1844    1823000
# 2712    1179000
# 1387    1438990
# 1007    1231000
# 1600     555000
# 33      1649000
# 846     1199000
# 1782     539000
# 185     1222000
#          ...
# 238     2168000
# 2744    1532000
# 83       629000
# 384      342000
# 440     1126000
# 2444     725000
# 2825     375000
# 1722    1179000
# 1340     529000
# 1735     632000
# 446     2465000
# 729     1407000
# 2390     693000
# 2033    2117000
# 337     2989000
# 685      805000
# 1794    2410000
# 2755     988000
# 1466     969000
# 67       554000
# 577     1275000
# 2221    1129000
# 1919    1944000
# 915     1274000
# ...

# %%
a = rf.predict(X_test)

# %%
a
# Out:
# array([1041931., 1060310., 1391800., 2735800., 1223249., 1758000.,
#        2076900., 1035900.,  761100., 1027483.,  761600.,  736333.,
#        1932000.,  734300., 1076739., 1278028., 1153400., 1064500.,
#        1267700., 2173200., 1228800., 2172200., 1047900., 1200600.,
#        1325900.,  598606., 1039856., 1065700.,  570000., 1128100.,
#        1752500., 1068378.,  490100., 1960300., 1277178., 1055500.,
#        1163000.,  846900., 1594900., 1504599.,  611604., 1195700.,
#        1041137.,  611200., 2192200.,  976354., 1179200., 1014600.,
#        1425598., 1852900., 1680200.,  875900., 1524900., 1149300.,
#        1074300.,  509904., 1095696., 1161680., 1230100.,  897000.,
#        1744700.,  696100.,  802100.,  761799., 1312000., 1358799.,
#        1494400.,  479834., 2139300.,  738800.,  619900., 1024020.,
#        1405800.,  997437., 2918800., 1298100., 1264800., 1407400.,
#        1113500., 2017200.,  695852., 2075000.,  913000.,  468334.,
# ...

# %%
pd.DataFrame(y_test)
# Out:
#            가격
# 2062  1001000
# 2381   879000
# 142   1300000
# 209   3000000
# 310   1360000
# 651   1705000
# 92    2199000
# 1966   903000
# 409    759000
# 1506   990000
# 2293   830000
# 1373   769990
# 473   1697000
# 2740   667000
# 1275  1272040
# 1299  1301490
# 1055  1199000
# 984   1180000
# 654   1163000
# 2179  1674000
# 87    1274000
# 1844  1823000
# 2712  1179000
# 1387  1438990
# 1007  1231000
# 1600   555000
# 33    1649000
# 846   1199000
# 1782   539000
# 185   1222000
# ...       ...
# 238   2168000
# 2744  1532000
# 83     629000
# 384    342000
# 440   1126000
# 2444   725000
# 2825   375000
# 1722  1179000
# 1340   529000
# 1735   632000
# 446   2465000
# 729   1407000
# 2390   693000
# 2033  2117000
# 337   2989000
# 685    805000
# 1794  2410000
# 2755   988000
# 1466   969000
# 67     554000
# 577   1275000
# 2221  1129000
# 1919  1944000
# 915   1274000
# 2870  1283000
# 2769  1495000
# 1121  1635000
# 1546  1075000
# 739   1027000
# 2440   679000
#
# ...

# %%
qw = pd.DataFrame(a, index=X_test['Unnamed: 1'])

# %%
qw.iloc[:,0]
# Out:
# Unnamed: 1
# 2063    1041931.0
# 2382    1060310.0
# 143     1391800.0
# 210     2735800.0
# 311     1223249.0
# 652     1758000.0
# 93      2076900.0
# 1967    1035900.0
# 410      761100.0
# 1507    1027483.0
# 2294     761600.0
# 1374     736333.0
# 474     1932000.0
# 2741     734300.0
# 1276    1076739.0
# 1300    1278028.0
# 1056    1153400.0
# 985     1064500.0
# 655     1267700.0
# 2180    2173200.0
# 88      1228800.0
# 1845    2172200.0
# 2713    1047900.0
# 1388    1200600.0
# 1008    1325900.0
# 1601     598606.0
# 34      1039856.0
# 847     1065700.0
# 1783     570000.0
# 186     1128100.0
#           ...
# 239     2164100.0
# 2745    1466100.0
# 84       737999.0
# 385      363600.0
# 441     1122200.0
# 2445     643508.0
# 2826     377900.0
# 1723    1181600.0
# 1341     705655.0
# 1736     591600.0
# 447     1124100.0
# 730      983900.0
# 2391     968932.0
# 2034    2196200.0
# 338     2751900.0
# 686      916258.0
# 1795    2401800.0
# 2756     754300.0
# ...

# %%
qw['answer'] = y_test

# %%
pd.concat([qw, value3])
# Out:
# D:\ana\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#               0     answer  Unnamed: 1
# 2063  1041931.0        NaN         NaN
# 2382  1060310.0        NaN         NaN
# 143   1391800.0        NaN         NaN
# 210   2735800.0  1037000.0         NaN
# 311   1223249.0        NaN         NaN
# 652   1758000.0        NaN         NaN
# 93    2076900.0        NaN         NaN
# 1967  1035900.0   370000.0         NaN
# 410    761100.0        NaN         NaN
# 1507  1027483.0        NaN         NaN
# 2294   761600.0        NaN         NaN
# 1374   736333.0   684990.0         NaN
# 474   1932000.0        NaN         NaN
# 2741   734300.0        NaN         NaN
# ...

# %%
value2 = pd.DataFrame(y_test, columns= ['answer'])

# %%
value2['predict'] = a

# %%
value2
# Out:
#     answer       predict
# 0      NaN  1.349200e+06
# 1      NaN  9.171200e+05
# 2      NaN  1.712850e+06
# 3      NaN  1.482600e+06
# 4      NaN  9.107323e+05
# 5      NaN  7.159018e+05
# 6      NaN  1.068551e+06
# 7      NaN  7.547720e+05
# 8      NaN  1.504300e+06
# 9      NaN  9.118000e+05
# 10     NaN  8.853068e+05
# 11     NaN  8.517000e+05
# 12     NaN  2.762600e+06
# 13     NaN  1.281098e+06
# 14     NaN  8.865633e+05
# 15     NaN  1.247610e+06
# 16     NaN  1.077758e+06
# 17     NaN  2.784000e+06
# 18     NaN  1.043500e+06
# 19     NaN  8.127000e+05
# 20     NaN  1.455633e+06
# 21     NaN  2.961000e+06
# 22     NaN  8.371000e+05
# 23     NaN  1.342350e+06
# 24     NaN  1.543000e+06
# 25     NaN  2.217885e+06
# 26     NaN  1.022128e+06
# 27     NaN  9.810000e+05
# 28     NaN  1.625606e+06
# 29     NaN  1.876400e+06
# ..     ...           ...
# 711    NaN  1.041700e+06
# 712    NaN  1.141500e+06
# 713    NaN  1.244460e+06
# 714    NaN  9.151000e+05
# 715    NaN  1.708991e+06
# ...
